# %% [markdown]
# # Investigating the Optimality Gap for Gitcoin Grants
#
# Source: https://hackmd.io/QCCJWZE0Ru27X_GRk6UKjQ

# %% [markdown]
# ## Dependences

# %%
load_ext autotime
# Out:
# time: 1.12 ms (started: 2021-01-20 16:58:59 -03:00)

# %%
# Library dependences
import cloudpickle
#import holoviews as hv
import networkx as nx

# Local dependences
#from model.parts.utils import plot_contributions
from optimality_gap.functions import total_amount
from optimality_gap.functions import contributions_to_graph
# Out:
# time: 1.94 s (started: 2021-01-20 16:58:59 -03:00)

# %%
#hv.extension('bokeh')
# Out:
# time: 1.01 ms (started: 2021-01-20 16:59:01 -03:00)

# %% [markdown]
# ## Load data from Pickle file

# %%
from env_config import PICKLE_PATH

# Load the data generated by the cadCAD simulation
with open(PICKLE_PATH, 'rb') as fid:
    result = cloudpickle.load(fid)
# Out:
# time: 49.7 ms (started: 2021-01-20 16:59:01 -03:00)

# %%
result.iloc[2].contributions
# Out:
# [{'time_sequence': 0,
#   'contributor': 'a0b99288e1',
#   'grant': 'Coin Center is educating policy makers about public blockchains',
#   'amount': 95.0,
#   'flag': 0},
#  {'time_sequence': 1,
#   'contributor': '55d1f7cbf0',
#   'grant': 'Bankless',
#   'amount': 39.89999999999999,
#   'flag': 0}]
# time: 55.2 ms (started: 2021-01-20 16:59:02 -03:00)

# %% [markdown]
# ## Load graph

# %%
# Generate a time series of NetworkX graphs
graphs = result.contributions.map(contributions_to_graph)
# Out:
# time: 819 ms (started: 2021-01-20 16:59:02 -03:00)

# %%
GRAPH_INDEX = 15
G = contributions_to_graph(result.iloc[GRAPH_INDEX].contributions)
# Out:
# time: 13.7 ms (started: 2021-01-20 16:59:02 -03:00)

# %% [markdown]
# plot_contributions(result.contributions.iloc[GRAPH_INDEX])

# %% [markdown]
# fig = (hv.Graph.from_networkx(G, nx.layout.fruchterman_reingold_layout, k=1)
#          .opts(tools=['hover']))
#
# colors = ['#000000']+hv.Cycle('Category20').values
#
# fig.opts(cmap=colors, node_color='type')

# %% [markdown]
# ## Retrieve optimality gap data

# %%
from optimality_gap.definitions import graph_optimality_gap_distribution
# Out:
# time: 225 ms (started: 2021-01-20 16:59:02 -03:00)

# %%
graph_optimality_gap_distribution(G)
# Out:
# HBox(children=(HTML(value='Calculating optimality gap'), FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# Optimizing subgraph
# HBox(children=(HTML(value='Sweeping edges'), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# time: 1.88 s (started: 2021-01-20 16:59:03 -03:00)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Conclusions
